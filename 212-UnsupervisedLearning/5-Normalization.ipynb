# %%
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# ## Normalize basic list data

# %%
# Import the whiten function
from scipy.cluster.vq import whiten
goals_for = [4,3,2,3,1,1,2,0,1,4]
# Use the whiten() function to standardize the data
scaled_data = whiten(goals_for)
print(scaled_data)
# Out:
# [3.07692308 2.30769231 1.53846154 2.30769231 0.76923077 0.76923077
#  1.53846154 0.         0.76923077 3.07692308]

# %%
# Plot original data
plt.plot(goals_for, label='original')
# Plot scaled data
plt.plot(scaled_data, label='scaled')
# Show the legend in the plot
plt.legend()
# Display the plot
plt.show()

# %% [markdown]
# ## Normalization of small numbers

# %%
# Prepare data
rate_cuts = [0.0025, 0.001, -0.0005, -0.001, -0.0005, 0.0025, -0.001, -0.0015, -0.001, 0.0005]
# Use the whiten() function to standardize the data
scaled_data = whiten(rate_cuts)
# Plot original data
plt.plot(rate_cuts, label='original')
# Plot scaled data
plt.plot(scaled_data, label='scaled')
plt.legend()
plt.show()

# %% [markdown]
# ## Normalize FIFA 18 data

# %%
filePath = "../datasets/fifa_18_sample_data.csv"

fifa = pd.read_csv(filePath, index_col=False)
print("DF Shape (Rows,Columns)=", fifa.shape)
# Out:
# DF Shape (Rows,Columns)= (1000, 185)

# %%
# Scale wage and value
fifa['scaled_wage'] = whiten(fifa['eur_wage'])
fifa['scaled_value'] = whiten(fifa['eur_value'])


# Plot the two columns in a scatter plot
fifa.plot(x='scaled_wage', y='scaled_value', kind='scatter')
plt.show()

# %%
# Check mean and standard deviation of scaled values
# scaled values should have a standard deviation of 1
print(fifa[['scaled_wage', 'scaled_value']].describe())
# Out:
#        scaled_wage  scaled_value
# count  1000.000000   1000.000000
# mean      1.119812      1.306272
# std       1.000500      1.000500
# min       0.000000      0.000000
# 25%       0.467717      0.730412
# 50%       0.854794      1.022576
# 75%       1.407184      1.542995
# max       9.112425      8.984064
